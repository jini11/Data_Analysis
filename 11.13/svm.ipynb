# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import confusion_matrix, classification_report


df = pd.read_csv('/content/preprocessing.csv')

df.head()
# Out:
# Error in callback <bound method _WandbInit._resume_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7efd0758bd10>> (for pre_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _resume_backend(self)
#     278         if self.backend is not None:
#     279             logger.info("resuming backend")
# --> 280             self.backend.interface.publish_resume()
#     281
#     282     def _jupyter_teardown(self):
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     543     def publish_resume(self) -> None:
#     544         resume = pb.ResumeRequest()
# --> 545         self._publish_resume(resume)
#     546
#     547     @abstractmethod
#
# ...

# %%
df_tt = df[['rain']].astype('int')

df_yy = df[['total count']].astype('int')

# %%
df_new = df.groupby('Rent day').mean()

df_new.head()
# Out:
# Error in callback <bound method _WandbInit._resume_backend of <wandb.sdk.wandb_init._WandbInit object at 0x7efd0758bd10>> (for pre_run_cell):
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_init.py in _resume_backend(self)
#     278         if self.backend is not None:
#     279             logger.info("resuming backend")
# --> 280             self.backend.interface.publish_resume()
#     281
#     282     def _jupyter_teardown(self):
#
# /usr/local/lib/python3.7/dist-packages/wandb/sdk/interface/interface.py in publish_resume(self)
#     543     def publish_resume(self) -> None:
#     544         resume = pb.ResumeRequest()
# --> 545         self._publish_resume(resume)
#     546
#     547     @abstractmethod
#
# ...

# %%
df_weather = df_new[['temp','rain','windspeed','humidity','snow']]

df_weather.head()

df_weather = df_weather.astype('int')

df_y = df_new[['total count']]

df_y.head()

df_y = df_y.astype('int')

# %%
#test, train data split
x_train, x_test, y_train, y_test = train_test_split(df_weather,df_yy, test_size=0.3, random_state=20)

len(x_train),len(x_test)

# %%
scores = []

model=SVC(kernel='linear')

#for thisC in [*range(1,100)]:
model=model.fit(x_train,y_train)
scoreTrain=model.score(x_train,y_train)
scoreTest=model.score(x_test,y_test) 
print("선형 SVM : C:{}, training score:{:2f}, test score:{:2f}".format
      (thisC,scoreTrain, scoreTest))
scores.append([scoreTrain, scoreTest])
# Out:
# 선형 SVM : C:3, training score:0.036387, test score:0.029168
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 선형 SVM : C:4, training score:0.036387, test score:0.029168
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 선형 SVM : C:5, training score:0.036387, test score:0.029168
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
