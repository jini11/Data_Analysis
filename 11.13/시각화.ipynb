# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/content/preprocessing.csv')

df.head()
# Out:
#      Rent day  Time month  temp  rain  windspeed  humidity  snow  total count
# 0  2020-07-01     0  july  18.9   0.0        3.0        87   0.0         26.0
# 1  2020-07-01     1  july  18.8   0.0        3.0        87   0.0          9.0
# 2  2020-07-01     2  july  18.7   0.0        3.0        87   0.0          7.0
# 3  2020-07-01     3  july  18.4   0.0        2.3        86   0.0          7.0
# 4  2020-07-01     4  july  18.2   0.0        1.2        86   0.0          4.0

# %%
df_new_temp = df[3672:6000]

df_t = df_new_temp.groupby('Rent day').mean()

df_t['day'] = 0

df_t['day'] = np.arange(1, 98)

# %%
df_new_rain = df[0:1500]

df_r = df_new_rain.groupby('Rent day').mean()

df_r['day'] = 0

df_r['day'] = np.arange(1,64)

# %%
df_day = df.groupby('Rent day').mean()

df_day['day']=0

df_day['day'] = np.arange(1,320)
#df_day['day'] = pd.date_range('2020-07-01','2021-05-15', freq='D')
df_day
# Out:
#             Time       temp      rain  ...  snow  total count  day
# Rent day                               ...
# 2020-07-01  11.5  20.975000  0.000000  ...   0.0   119.375000    1
# 2020-07-02  11.5  24.029167  0.000000  ...   0.0   125.916667    2
# 2020-07-03  11.5  25.658333  0.000000  ...   0.0   120.625000    3
# 2020-07-04  11.5  24.008333  0.070833  ...   0.0   138.583333    4
# 2020-07-05  11.5  23.683333  0.000000  ...   0.0   142.625000    5
# ...          ...        ...       ...  ...   ...          ...  ...
# 2021-05-27  11.5  16.154167  0.370833  ...   0.0    43.083333  315
# 2021-05-28  11.5  15.079167  0.512500  ...   0.0    43.125000  316
# 2021-05-29  11.5  15.654167  0.012500  ...   0.0    39.625000  317
# 2021-05-30  11.5  18.029167  0.387500  ...   0.0    85.583333  318
# 2021-05-31  11.5  19.687500  0.533333  ...   0.0   101.125000  319
#
# [319 rows x 8 columns]

# %%
plt.style.use('ggplot')

size = plt.figure(figsize=(40,30))

ax1 = size.add_subplot(4,1,1)
ax2 = size.add_subplot(4,1,2)
ax3 = size.add_subplot(4,1,3)
ax4 = size.add_subplot(4,1,4)

label=['2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01']
day = pd.date_range('2020-07-01','2021-05-31',freq='D')

ax1.bar(df_day['day'], df_day['total count'], color='olive',label='total count')
ax1.plot( df_day['temp'], marker='.', markersize =10, markerfacecolor='blue', 
         color='skyblue', linewidth=2, label='temp')
ax1.set_xticklabels(xticks =[0,30,60,90,120,150,180,210,240,270,300,330], labels=['2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01'],
                    rotation='vertical') 
 
plt.show()

# %%
#자전거 대여수, 기온
fig = plt.figure(figsize=(40,5)) ## 캔버스 생성
ax1 = fig.add_subplot() ## axes 생성

ax1.bar(df_day['day'], df_day['total count'], color='olive')
ax1.set_xticks([0,30,60,90,120,150,180,210,240,270,300])
ax1.set_xticklabels(['2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01'],
                    rotation=45)
ax1.set_ylabel('num', color='olive')
ax1.tick_params(axis='y', labelcolor='olive')

ax3 = ax1.twinx()
ax3.plot(df_day['day'], df_day['temp'], color='skyblue', marker='.', markersize=10, markerfacecolor='blue')
ax3.set_ylabel('temp_avg', color='skyblue')
ax3.tick_params(axis='y', labelcolor='skyblue')

# %%
#자전거 대여수, 기온
fig = plt.figure(figsize=(18,5)) ## 캔버스 생성
ax1 = fig.add_subplot() ## axes 생성

ax1.bar(df_t['day'], df_t['total count'], color='olive')
ax1.set_xticks([0,30,60,90,120,150,180,210,240,270,300])
ax1.set_xticklabels(['2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01'],
                    rotation=45)
ax1.set_ylabel('num', color='olive')
ax1.tick_params(axis='y', labelcolor='olive')

ax3 = ax1.twinx()
ax3.plot(df_t['day'], df_t['temp'], color='skyblue', marker='.', markersize=10, markerfacecolor='blue')
ax3.set_ylabel('temp_avg', color='skyblue')
ax3.tick_params(axis='y', labelcolor='skyblue')

# %%
#자전거 대여수, 비
fig = plt.figure(figsize=(40,5)) ## 캔버스 생성
ax1 = fig.add_subplot() ## axes 생성
 
ax1.bar(df_day['day'], df_day['total count'], color='olive')
ax1.set_xticks([0,30,60,90,120,150,180,210,240,270,300])
ax1.set_xticklabels(['2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01'],
                    rotation=45)
ax1.set_ylabel('num', color='olive')
ax1.tick_params(axis='y', labelcolor='olive')

ax3 = ax1.twinx()
ax3.plot(df_day['day'], df_day['rain'], color='magenta', marker='.', markersize=8, markerfacecolor='red')
ax3.set_ylabel('rain_avg', color='magenta')
ax3.tick_params(axis='y', labelcolor='magenta')

# %%
#자전거 대여수, 비
fig = plt.figure(figsize=(18,5)) ## 캔버스 생성
ax1 = fig.add_subplot() ## axes 생성
 
ax1.bar(df_r['day'], df_r['total count'], color='olive')
ax1.set_xticks([0,30,60,90,120,150,180,210,240,270,300])
ax1.set_xticklabels(['2020-07-01', '2020-08-01', '2020-09-01'],
                    rotation=45)
ax1.set_ylabel('num', color='olive')
ax1.tick_params(axis='y', labelcolor='olive')

ax3 = ax1.twinx()
ax3.plot(df_r['day'], df_r['rain'], color='magenta', marker='.', markersize=8, markerfacecolor='red')
ax3.set_ylabel('rain_avg', color='magenta')
ax3.tick_params(axis='y', labelcolor='magenta')

# %%
#자전거 대여수, 풍속
fig = plt.figure(figsize=(40,5)) ## 캔버스 생성
ax1 = fig.add_subplot() ## axes 생성
 
ax1.bar(df_day['day'], df_day['total count'], color='olive')
ax1.set_xticks([0,30,60,90,120,150,180,210,240,270,300])
ax1.set_xticklabels(['2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01'],
                    rotation=45)
ax1.set_ylabel('num', color=color1)
ax1.tick_params(axis='y', labelcolor=color1)

ax3 = ax1.twinx()
ax3.plot(df_day['day'], df_day['windspeed'], color='red', marker='.', markersize=8, markerfacecolor='orange')
ax3.set_ylabel('windspeed_avg', color=color3)
ax3.tick_params(axis='y', labelcolor=color3)

# %%
#자전거 대여수, 습도
fig = plt.figure(figsize=(40,5)) ## 캔버스 생성
ax1 = fig.add_subplot() ## axes 생성
 
ax1.bar(df_day['day'], df_day['total count'], color='olive')
ax1.set_xticks([0,30,60,90,120,150,180,210,240,270,300])
ax1.set_xticklabels(['2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01'],
                    rotation=45)
ax1.set_ylabel('num', color='olive')
ax1.tick_params(axis='y', labelcolor='olive')

ax3 = ax1.twinx()
ax3.plot(df_day['day'], df_day['humidity'], color='yellow', marker='.', markersize=8, markerfacecolor='orange')
ax3.set_ylabel('humidity_avg', color='yellow')
ax3.tick_params(axis='y', labelcolor='yellow')

# %%
#자전거 대여수, 눈
fig = plt.figure(figsize=(40,5)) ## 캔버스 생성
ax1 = fig.add_subplot() ## axes 생성
 
ax1.bar(df_day['day'], df_day['total count'], color='olive')
ax1.set_xticks([0,30,60,90,120,150,180,210,240,270,300])
ax1.set_xticklabels(['2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01', '2021-05-01'],
                    rotation=45)
ax1.set_ylabel('num', color='olive')
ax1.tick_params(axis='y', labelcolor='olive')

ax3 = ax1.twinx()
ax3.plot(df_day['day'], df_day['snow'], color='violet', marker='.', markersize=8, markerfacecolor='purple')
ax3.set_ylabel('snow_avg', color='violet')
ax3.tick_params(axis='y', labelcolor='violet')

# %%
#자전거 대여수, 눈
fig = plt.figure(figsize=(18,5)) ## 캔버스 생성
ax1 = fig.add_subplot() ## axes 생성
 
ax1.bar(df_t['day'], df_t['total count'], color='olive')
ax1.set_xticks([0,30,60,90,120,150,180,210,240,270,300])
ax1.set_xticklabels(['2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01'],
                    rotation=45)
ax1.set_ylabel('num', color='olive')
ax1.tick_params(axis='y', labelcolor='olive')

ax3 = ax1.twinx()
ax3.plot(df_t['day'], df_t['snow'], color='violet', marker='.', markersize=8, markerfacecolor='purple')
ax3.set_ylabel('snow_avg', color='violet')
ax3.tick_params(axis='y', labelcolor='violet')
